# %%
import numpy as np

# %%
list_input = [1.0, 0.5, -1.5]
nparr_input = np.array(list_input, ndmin=2)
print(type(nparr_input))
print(nparr_input)
print(nparr_input.ndim)
# Out:
# <class 'numpy.ndarray'>
# [[ 1.   0.5 -1.5]]
# 2
